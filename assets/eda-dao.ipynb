# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#              Date                                            Address  \
# 0      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2      2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5      2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6      2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 7      2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 8      2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 9      2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 10     2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 11     2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 12     2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# ...

# %%
matplotlib inline

# %%
ts = df.NumMosquitos.cumsum()
ts.plot()

# %%
def eda(dataframe):
    print "missing values \n", dataframe.isnull().sum() #count how many null values are in each series
    print "dataframe types \n", dataframe.dtypes # check data types of each colum
    print "dataframe shape \n", dataframe.shape # gives us the number of rows and columns
    print "dataframe describe \n", dataframe.describe() # descriptive statistics
    for item in dataframe:
        print item
        print dataframe[item].nunique() # print number of unique observations

# %%
eda(df)
# Out:
# missing values
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# dtype: int64
# dataframe types
# Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# NumMosquitos                int64
# WnvPresent                  int64
# dtype: object
# dataframe shape
# (10506, 12)
# dataframe describe
#               Block      Latitude     Longitude  AddressAccuracy  \
# ...

# %%
df.shape
# Out:
# (10506, 12)

# %%
df.sort_values('Trap')
# Out:
#              Date                                            Address  \
# 359    2007-07-11    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 2269   2007-08-21    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 3102   2007-09-12    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 1896   2007-08-15    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 1895   2007-08-15    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 3677   2007-10-04    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 1567   2007-08-07    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 1566   2007-08-07    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 3678   2007-10-04    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 973    2007-08-01    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 972    2007-08-01    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 971    2007-08-01    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 2604   2007-08-24    4000 North Tripp Avenue, Chicago, IL 60641, USA
# ...

# %%
df.sort_values('Trap').Trap.unique()
# Out:
# array(['T001', 'T002', 'T003', 'T004', 'T005', 'T006', 'T007', 'T008',
#        'T009', 'T011', 'T012', 'T013', 'T014', 'T015', 'T016', 'T017',
#        'T018', 'T019', 'T025', 'T027', 'T028', 'T030', 'T031', 'T033',
#        'T034', 'T035', 'T036', 'T037', 'T039', 'T040', 'T043', 'T044',
#        'T045', 'T046', 'T047', 'T048', 'T049', 'T050', 'T051', 'T054',
#        'T054C', 'T060', 'T061', 'T062', 'T063', 'T065', 'T066', 'T067',
#        'T069', 'T070', 'T071', 'T072', 'T073', 'T074', 'T075', 'T076',
#        'T077', 'T078', 'T079', 'T080', 'T081', 'T082', 'T083', 'T084',
#        'T085', 'T086', 'T088', 'T089', 'T090', 'T091', 'T092', 'T094',
#        'T094B', 'T095', 'T096', 'T097', 'T099', 'T100', 'T102', 'T103',
#        'T107', 'T114', 'T115', 'T128', 'T129', 'T135', 'T138', 'T141',
#        'T142', 'T143', 'T144', 'T145', 'T146', 'T147', 'T148', 'T149',
#        'T150', 'T151', 'T152', 'T153', 'T154', 'T155', 'T156', 'T157',
# ...

# %%
df.sort_values('AddressAccuracy').AddressAccuracy.unique()
# Out:
# array([3, 5, 8, 9])

# %%
df.describe()
# Out:
#               Block      Latitude     Longitude  AddressAccuracy  \
# count  10506.000000  10506.000000  10506.000000     10506.000000
# mean      35.687797     41.841139    -87.699908         7.819532
# std       24.339468      0.112742      0.096514         1.452921
# min       10.000000     41.644612    -87.930995         3.000000
# 25%       12.000000     41.732984    -87.760070         8.000000
# 50%       33.000000     41.846283    -87.694991         8.000000
# 75%       52.000000     41.954690    -87.627796         9.000000
# max       98.000000     42.017430    -87.531635         9.000000
#
#        NumMosquitos    WnvPresent
# count  10506.000000  10506.000000
# mean      12.853512      0.052446
# std       16.133816      0.222936
# min        1.000000      0.000000
# 25%        2.000000      0.000000
# 50%        5.000000      0.000000
# 75%       17.000000      0.000000
# max       50.000000      1.000000

# %%
df[df.WnvPresent == 1].describe(include=['object'])
# Out:
#               Date                                            Address  \
# count          551                                                551
# unique          53                                                 99
# top     2013-08-29  ORD Terminal 5, O'Hare International Airport, ...
# freq            38                                                 66
#
#                        Species            Street  Trap  \
# count                      551               551   551
# unique                       3                92    97
# top     CULEX PIPIENS/RESTUANS   W OHARE AIRPORT  T900
# freq                       262                66    66
#
#                     AddressNumberAndStreet
# count                                  551
# unique                                  99
# top     1000  W OHARE AIRPORT, Chicago, IL
# freq                                    66

# %%
df[df.WnvPresent == 1].Species.unique()
# Out:
# array(['CULEX PIPIENS/RESTUANS', 'CULEX PIPIENS', 'CULEX RESTUANS'], dtype=object)

# %%
df.Species.unique()
# Out:
# array(['CULEX PIPIENS/RESTUANS', 'CULEX RESTUANS', 'CULEX PIPIENS',
#        'CULEX SALINARIUS', 'CULEX TERRITANS', 'CULEX TARSALIS',
#        'CULEX ERRATICUS'], dtype=object)

# %%
# List of all the traps that had mosquitos with WNV.
df[df.WnvPresent == 1].Trap.unique()
# Out:
# array(['T215', 'T115', 'T002', 'T015', 'T086', 'T096', 'T090', 'T135',
#        'T220', 'T008', 'T144', 'T065', 'T081', 'T082', 'T138', 'T103',
#        'T212', 'T143', 'T011', 'T016', 'T162', 'T014', 'T160', 'T128',
#        'T209', 'T045', 'T048', 'T049', 'T009', 'T033', 'T142', 'T145',
#        'T154', 'T158', 'T003', 'T006', 'T012', 'T035', 'T061', 'T066',
#        'T074', 'T114', 'T155', 'T221', 'T089', 'T151', 'T084', 'T036',
#        'T039', 'T070', 'T094', 'T159', 'T200', 'T107', 'T097', 'T152',
#        'T005', 'T095', 'T073', 'T080', 'T083', 'T028', 'T037', 'T063',
#        'T091', 'T085', 'T067', 'T062', 'T156', 'T031', 'T225', 'T102',
#        'T900', 'T903', 'T230', 'T228', 'T013', 'T223', 'T027', 'T218',
#        'T231', 'T030', 'T226', 'T054', 'T079', 'T147', 'T227', 'T224',
#        'T233', 'T047', 'T235', 'T054C', 'T232', 'T222', 'T069', 'T077',
#        'T236'], dtype=object)

# %%
df.Trap.unique()
# Out:
# array(['T002', 'T007', 'T015', 'T045', 'T046', 'T048', 'T049', 'T050',
#        'T054', 'T086', 'T091', 'T094', 'T096', 'T129', 'T143', 'T148',
#        'T153', 'T159', 'T009', 'T011', 'T016', 'T019', 'T025', 'T028',
#        'T031', 'T033', 'T089', 'T090', 'T092', 'T135', 'T141', 'T142',
#        'T145', 'T146', 'T147', 'T149', 'T150', 'T151', 'T152', 'T154',
#        'T158', 'T162', 'T218', 'T220', 'T001', 'T003', 'T006', 'T008',
#        'T012', 'T034', 'T037', 'T040', 'T043', 'T047', 'T051', 'T085',
#        'T088', 'T161', 'T219', 'T013', 'T014', 'T018', 'T030', 'T084',
#        'T144', 'T160', 'T005', 'T017', 'T044', 'T095', 'T004', 'T035',
#        'T036', 'T039', 'T060', 'T061', 'T062', 'T065', 'T066', 'T067',
#        'T069', 'T070', 'T071', 'T073', 'T074', 'T075', 'T076', 'T077',
#        'T079', 'T080', 'T081', 'T082', 'T083', 'T114', 'T155', 'T063',
#        'T115', 'T138', 'T200', 'T206', 'T209', 'T212', 'T215', 'T107',
# ...

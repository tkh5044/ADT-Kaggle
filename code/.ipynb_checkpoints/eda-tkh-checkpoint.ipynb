# %%
import pandas as pd
import numpy as np
import pandas_profiling as pdp

# %%
df_train = pd.read_csv('../assets/train.csv')

# %%
pdp.ProfileReport(df_train)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
df_train.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# ...

# %%
df_train.shape
# Out:
# (10506, 12)

# %%
df_train.sort_values('Trap')
# Out:
#              Date                                            Address  \
# 359    2007-07-11    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 2269   2007-08-21    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 3102   2007-09-12    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 1896   2007-08-15    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 1895   2007-08-15    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 3677   2007-10-04    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 1567   2007-08-07    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 1566   2007-08-07    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 3678   2007-10-04    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 973    2007-08-01    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 972    2007-08-01    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 971    2007-08-01    4000 North Tripp Avenue, Chicago, IL 60641, USA
# 2604   2007-08-24    4000 North Tripp Avenue, Chicago, IL 60641, USA
# ...

# %%
df_train.sort_values('Trap').Trap.unique()
# Out:
# array(['T001', 'T002', 'T003', 'T004', 'T005', 'T006', 'T007', 'T008',
#        'T009', 'T011', 'T012', 'T013', 'T014', 'T015', 'T016', 'T017',
#        'T018', 'T019', 'T025', 'T027', 'T028', 'T030', 'T031', 'T033',
#        'T034', 'T035', 'T036', 'T037', 'T039', 'T040', 'T043', 'T044',
#        'T045', 'T046', 'T047', 'T048', 'T049', 'T050', 'T051', 'T054',
#        'T054C', 'T060', 'T061', 'T062', 'T063', 'T065', 'T066', 'T067',
#        'T069', 'T070', 'T071', 'T072', 'T073', 'T074', 'T075', 'T076',
#        'T077', 'T078', 'T079', 'T080', 'T081', 'T082', 'T083', 'T084',
#        'T085', 'T086', 'T088', 'T089', 'T090', 'T091', 'T092', 'T094',
#        'T094B', 'T095', 'T096', 'T097', 'T099', 'T100', 'T102', 'T103',
#        'T107', 'T114', 'T115', 'T128', 'T129', 'T135', 'T138', 'T141',
#        'T142', 'T143', 'T144', 'T145', 'T146', 'T147', 'T148', 'T149',
#        'T150', 'T151', 'T152', 'T153', 'T154', 'T155', 'T156', 'T157',
# ...

# %%
df_train.sort_values('AddressAccuracy').AddressAccuracy.unique()
# Out:
# array([3, 5, 8, 9])

# %%
df_train.describe()
# Out:
#               Block      Latitude     Longitude  AddressAccuracy  \
# count  10506.000000  10506.000000  10506.000000     10506.000000
# mean      35.687797     41.841139    -87.699908         7.819532
# std       24.339468      0.112742      0.096514         1.452921
# min       10.000000     41.644612    -87.930995         3.000000
# 25%       12.000000     41.732984    -87.760070         8.000000
# 50%       33.000000     41.846283    -87.694991         8.000000
# 75%       52.000000     41.954690    -87.627796         9.000000
# max       98.000000     42.017430    -87.531635         9.000000
#
#        NumMosquitos    WnvPresent
# count  10506.000000  10506.000000
# mean      12.853512      0.052446
# std       16.133816      0.222936
# min        1.000000      0.000000
# 25%        2.000000      0.000000
# 50%        5.000000      0.000000
# 75%       17.000000      0.000000
# max       50.000000      1.000000

# %%
df_train[df_train.WnvPresent == 1].describe(include=['object'])
# Out:
#               Date                                            Address  \
# count          551                                                551
# unique          53                                                 99
# top     2013-08-29  ORD Terminal 5, O'Hare International Airport, ...
# freq            38                                                 66
#
#                        Species            Street  Trap  \
# count                      551               551   551
# unique                       3                92    97
# top     CULEX PIPIENS/RESTUANS   W OHARE AIRPORT  T900
# freq                       262                66    66
#
#                     AddressNumberAndStreet
# count                                  551
# unique                                  99
# top     1000  W OHARE AIRPORT, Chicago, IL
# freq                                    66

# %%
df_train[df_train.WnvPresent == 1].Species.unique()
# Out:
# array(['CULEX PIPIENS/RESTUANS', 'CULEX PIPIENS', 'CULEX RESTUANS'], dtype=object)

# %%
df_train.Species.unique()
# Out:
# array(['CULEX PIPIENS/RESTUANS', 'CULEX RESTUANS', 'CULEX PIPIENS',
#        'CULEX SALINARIUS', 'CULEX TERRITANS', 'CULEX TARSALIS',
#        'CULEX ERRATICUS'], dtype=object)

# %%
df_w = pd.read_csv('../assets/weather.csv')
df_w.sort_values('Date').head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
# 3    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 4    ...                0      M      0.0        0.00       29.39    30.12
#
#   ResultSpeed ResultDir  AvgSpeed
# ...

# %%
df_s = pd.read_csv('../assets/spray.csv')
df_s.sort_values('Date').describe
# Out:
# <bound method DataFrame.describe of              Date        Time   Latitude  Longitude
# 0      2011-08-29  6:56:58 PM  42.391623 -88.089163
# 69     2011-08-29  7:09:58 PM  42.390335 -88.096443
# 68     2011-08-29  7:09:48 PM  42.390642 -88.096440
# 67     2011-08-29  7:09:38 PM  42.390952 -88.096437
# 66     2011-08-29  7:09:28 PM  42.391238 -88.096468
# 65     2011-08-29  7:09:18 PM  42.391270 -88.096035
# 64     2011-08-29  7:09:08 PM  42.391275 -88.095608
# 63     2011-08-29  7:08:58 PM  42.391297 -88.095203
# 62     2011-08-29  7:08:48 PM  42.391518 -88.095143
# 61     2011-08-29  7:08:38 PM  42.391860 -88.095140
# 70     2011-08-29  7:10:08 PM  42.390048 -88.096435
# 60     2011-08-29  7:08:28 PM  42.392197 -88.095163
# 58     2011-08-29  7:07:38 PM  42.393678 -88.095593
# 57     2011-08-29  7:07:28 PM  42.393603 -88.095917
# 56     2011-08-29  7:07:18 PM  42.393488 -88.096267
# 55     2011-08-29  7:07:08 PM  42.393193 -88.096447
# ...

# %%
df_train.sort_values('Date').head()
# Out:
#           Date                                            Address  \
# 0   2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 24  2007-05-29  8900 South Carpenter Street, Chicago, IL 60620...
# 23  2007-05-29     1500 North Long Avenue, Chicago, IL 60651, USA
# 22  2007-05-29   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 21  2007-05-29  6500 North Oak Park Avenue, Chicago, IL 60631,...
#
#                    Species  Block           Street  Trap  \
# 0   CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 24          CULEX RESTUANS     89   S CARPENTER ST  T159
# 23          CULEX RESTUANS     15       N LONG AVE  T153
# 22  CULEX PIPIENS/RESTUANS     75     N OAKLEY AVE  T148
# 21  CULEX PIPIENS/RESTUANS     65   N OAK PARK AVE  T143
#
#                AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0   4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# ...

# %%
df_w.sort_values('Date')
df_w.sort_values('Station')
df_w.Station.unique()       # return the unique values
df_w.columns
df_w.dtypes
def eda(dataframe):
    print "missing values\n", dataframe.isnull().sum()  # count how many null values are in each series
    print('')                                           # creates a blank row
    print "dataframe types \n", dataframe.dtypes        # data types
    print('')
    print "dataframe shape \n", dataframe.shape         # row count, column count
    print('')
    print "dataframe describe \n", dataframe.describe() # count, mean, stand dev, min, max, Q1, Median, Q3
    print(' ')
    print 'duplicates \n', dataframe.duplicated().sum() # True if a row is identical to a previous row
#     print 'drop dups \n', dataframe.drop_duplicates()    # Drop the duplicate rows
    print(' ')
    print('number of unique values for each column')
    for item in dataframe:
        print item
        print(' ')
        print dataframe[item].nunique()                 # number of unique values for each column

print 'Weather Dataframe EDA'
print eda(df_w)
print 'Training Dataframe EDA'
print eda(df_train)
print ''
# Out:
# missing values
# Station        0
# Date           0
# Tmax           0
# Tmin           0
# Tavg           0
# Depart         0
# DewPoint       0
# WetBulb        0
# Heat           0
# Cool           0
# Sunrise        0
# Sunset         0
# CodeSum        0
# Depth          0
# Water1         0
# SnowFall       0
# PrecipTotal    0
# StnPressure    0
# SeaLevel       0
# ResultSpeed    0
# ResultDir      0
# AvgSpeed       0
# dtype: int64
#
# dataframe types
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg            object
# Depart          object
# DewPoint         int64
# WetBulb         object
# Heat            object
# Cool            object
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# ...
